# %%
import os
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("./suzyzzang.jfif", cv2.IMREAD_COLOR)
plt.imshow(img)

# %%
save_img_path = ROOT/'image'
if not os.path.isdir(save_img_path):
    os.mkdir(save_img_path)
imglist = os.listdir(save_img_path)
imgnum = len(imglist)
if os.path.isfile(save_img_path/f'{imgnum}.jpg'):
    cv2.imwrite(save_img_path/f'{str(imgnum+1)}.jpg', im0)
else:
    cv2.imwrite(save_img_path/f'{imgnum}.jpg', im0)
